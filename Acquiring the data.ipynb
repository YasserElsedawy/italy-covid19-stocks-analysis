# %%
import pandas as pd
import requests
import datetime 
import pandas_datareader.data as web
from yahoo_fin import stock_info as si

# %%
start = datetime.datetime(2019,12,30)
end = datetime.datetime(2020,4,21)
companies = ['AEF.MI','MONC.MI','BC.MI','SFER.MI','TOD.MI','MC.PA','CDI.PA','KER.PA']
data = web.DataReader(companies,'yahoo',start,end)

# %%
data
# Out:
# Attributes Adj Close                                                       \
# Symbols       AEF.MI    MONC.MI      BC.MI SFER.MI     TOD.MI       MC.PA
# Date
# 2019-12-30     1.994  40.070000  31.559999  18.750  41.220001  409.308960
# 2019-12-31       NaN        NaN        NaN     NaN        NaN  408.914062
# 2020-01-02     2.030  40.590000  32.340000  18.955  42.000000  413.800873
# 2020-01-03     2.000  40.090000  32.119999  18.605  40.639999  413.751526
# 2020-01-06     1.942  40.070000  31.799999  18.555  39.599998  409.851929
# ...              ...        ...        ...     ...        ...         ...
# 2020-04-15     1.058  33.209999  25.940001  12.060  28.100000  337.635468
# 2020-04-16     1.034  32.849998  26.540001  11.890  27.760000  338.425232
# 2020-04-17     1.054  34.520000  27.340000  12.150  28.340000  353.431274
# 2020-04-20     1.054  35.250000  28.400000  12.100  28.920000  355.850006
# 2020-04-21     1.054  34.000000  28.799999  11.390  28.000000  350.000000
#
# ...

# %%
data.to_csv('milan_stocks.csv')
